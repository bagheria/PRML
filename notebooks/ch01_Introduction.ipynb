# %% [markdown]
# # 1. Introduction

# %%
import sys
if "C:/Users/ayoub/PRML/" not in sys.path:
    sys.path.append("C:/Users/ayoub/PRML/")

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from prml.preprocess import PolynomialFeature
from prml.linear import (
    LinearRegression,
    RidgeRegression,
    BayesianRegression
)

np.random.seed(1234)

# %% [markdown]
# ## 1.1. Example: Polynomial Curve Fitting

# %%
def create_toy_data(func, sample_size, std):
    x = np.linspace(0, 2, sample_size)
    t = func(x) + np.random.normal(scale=std, size=x.shape)
    return x, t

def func(x):
    return np.sin(2 * np.pi * x)

x_train, y_train = create_toy_data(func, 50, 0.25)
x_test = np.linspace(0, 2, 100)
y_test = func(x_test)

plt.scatter(x_train, y_train, facecolor="g", edgecolor="b", s=20, label="training data")
plt.plot(x_test, y_test, c="green", label="$\sin(2\pi x)$")
plt.legend()
plt.show()

# %%
for i, degree in enumerate([0, 3, 7, 20]):
    plt.subplot(2, 2, i + 1)
    feature = PolynomialFeature(degree)
    X_train = feature.transform(x_train)
    X_test = feature.transform(x_test)

    model = LinearRegression()
    model.fit(X_train, y_train)
    y = model.predict(X_test)

    plt.scatter(x_train, y_train, facecolor="g", edgecolor="b", s=10, label="training data")
    plt.plot(x_test, y_test, c="g", label="$\sin(2\pi x)$")
    plt.plot(x_test, y, c="r", label="fitting")
    plt.ylim(-1.5, 1.5)
    plt.annotate("M={}".format(degree), xy=(-0.15, 1))
plt.legend(bbox_to_anchor=(1.05, 0.64), loc=2, borderaxespad=0.)
plt.show()

# %%
def rmse(a, b):
    return np.sqrt(np.mean(np.square(a - b)))

training_errors = []
test_errors = []

for i in range(20):
    feature = PolynomialFeature(i)
    X_train = feature.transform(x_train)
    X_test = feature.transform(x_test)

    model = LinearRegression()
    model.fit(X_train, y_train)
    y = model.predict(X_test)
    training_errors.append(rmse(model.predict(X_train), y_train))
    test_errors.append(rmse(model.predict(X_test), y_test + np.random.normal(scale=0.25, size=len(y_test))))

plt.plot(training_errors, 'o-', mfc="none", mec="b", ms=10, c="b", label="Training")
plt.plot(test_errors, 'o-', mfc="none", mec="r", ms=10, c="r", label="Test")
plt.legend()
plt.xlabel("degree")
plt.ylabel("RMSE")
plt.show()

# %% [markdown]
# #### Regularization

# %%
feature = PolynomialFeature(12)
X_train = feature.transform(x_train)
X_test = feature.transform(x_test)

model = RidgeRegression(alpha=1e-3)
model.fit(X_train, y_train)
y = model.predict(X_test)

y = model.predict(X_test)
plt.scatter(x_train, y_train, facecolor="none", edgecolor="b", s=50, label="training data")
plt.plot(x_test, y_test, c="g", label="$\sin(2\pi x)$")
plt.plot(x_test, y, c="r", label="fitting")
plt.ylim(-1.5, 1.5)
plt.legend()
plt.annotate("M=9", xy=(-0.15, 1))
plt.show()

# %% [markdown]
# ### 1.2.6 Bayesian curve fitting

# %%
model = BayesianRegression(alpha=2e-3, beta=2)
model.fit(X_train, y_train)

y, y_err = model.predict(X_test, return_std=True)
plt.scatter(x_train, y_train, facecolor="none", edgecolor="b", s=50, label="training data")
plt.plot(x_test, y_test, c="g", label="$\sin(2\pi x)$")
plt.plot(x_test, y, c="r", label="mean")
plt.fill_between(x_test, y - y_err, y + y_err, color="pink", label="std.", alpha=0.5)
plt.xlim(-0.1, 1.9)
plt.ylim(-1.5, 1.5)
plt.annotate("M=9", xy=(0.8, 1))
plt.legend(bbox_to_anchor=(1.05, 1.), loc=2, borderaxespad=0.)
plt.show()

# %%
a = np.random.randn(9, 5)
a
# Out:
# array([[ 0.62118119, -0.13874982, -0.4383907 , -0.4242054 , -0.63873285],
#        [-0.48468508, -0.60584064, -2.01550455,  1.79735792,  0.07639164],
#        [-2.46291758,  0.45366869, -1.03202734, -1.03275658,  0.15756702],
#        [-1.32161448,  0.04894549,  1.25190202,  0.55193165, -0.83737277],
#        [-0.26801991,  1.37297789, -0.36874048, -1.7012183 ,  0.73807712],
#        [ 0.63935557,  0.15873225, -0.98694602, -1.27213012,  0.40144959],
#        [ 1.08743829,  0.68706873,  1.0143633 ,  0.34683559,  0.95431252],
#        [ 0.3119476 , -0.3605385 ,  0.18951027,  0.90099726, -0.51226251],
#        [ 0.18821971, -0.21150136,  2.09861815,  0.00488757,  0.05969426]])
